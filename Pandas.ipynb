# %%
import pandas as pd 
import numpy as np

# %%
data=pd.read_csv("titanic.csv")

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.dtypes == 'object'
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
data.dtypes[data.dtypes == 'object']
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
data[data.dtypes[data.dtypes == 'object'].index]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
data[data.dtypes[data.dtypes == 'object'].index].describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
data.dtypes == 'float'
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare            True
# Cabin          False
# Embarked       False
# dtype: bool

# %%
data.dtypes == 'int'
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age            False
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin          False
# Embarked       False
# dtype: bool

# %%
data.dtypes[0:3]
# Out:
# PassengerId    int64
# Survived       int64
# Pclass         int64
# dtype: object

# %%
data[['Survived']][3:10]
# Out:
#    Survived
# 3         1
# 4         0
# 5         0
# 6         0
# 7         0
# 8         1
# 9         1

# %%
data[['new_col']] = 0

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data['new_col'] = data['PassengerId'] + data['Pclass']

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pd.Categorical(data['Pclass'])
# Out:
# [3, 1, 3, 1, 3, ..., 2, 1, 3, 1, 3]
# Length: 891
# Categories (3, int64): [1, 2, 3]

# %%
pd.Categorical(data['Sex'])
# Out:
# ['male', 'female', 'female', 'female', 'male', ..., 'male', 'female', 'female', 'male', 'male']
# Length: 891
# Categories (2, object): ['female', 'male']

# %%
data['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
data[data['Age']>18]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
len(data[data['Age']>18])
# Out:
# 575

# %%
data[data['Fare']==0]
# Out:
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 179          180         0       3               Leonard, Mr. Lionel  male
# 263          264         0       1             Harrison, Mr. William  male
# 271          272         1       3      Tornquist, Mr. William Henry  male
# 277          278         0       2       Parkes, Mr. Francis "Frank"  male
# 302          303         0       3   Johnson, Mr. William Cahoone Jr  male
# 413          414         0       2    Cunningham, Mr. Alfred Fleming  male
# 466          467         0       2             Campbell, Mr. William  male
# 481          482         0       2  Frost, Mr. Anthony Wood "Archie"  male
# 597          598         0       3               Johnson, Mr. Alfred  male
# 633          634         0       1     Parr, Mr. William Henry Marsh  male
# 674          675         0       2        Watson, Mr. Ennis Hastings  male
# ...

# %%
data[data['Sex']== 'male']
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked  new_col
# ...

# %%
data[(data['Sex'] == 'female') & ( data['Fare'] > 32)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 31            32         1       1
# 43            44         1       2
# 52            53         1       1
# ..           ...       ...     ...
# 853          854         1       1
# 856          857         1       1
# 863          864         0       3
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 43            Laroche, Miss. Simonne Marie Anne Andree  female   3.0      1
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
s = data['Name']

# %%
s
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
len(s)
# Out:
# 891

# %%
s= data['Name'][0:10]

# %%
s
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# 7                       Palsson, Master. Gosta Leonard
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                  Nasser, Mrs. Nicholas (Adele Achem)
# Name: Name, dtype: object

# %%
l = ['a','b','c','d','e','f','g','h','i','j']

# %%
sl = pd.Series(list(s) , index=l)

# %%
s
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# 7                       Palsson, Master. Gosta Leonard
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                  Nasser, Mrs. Nicholas (Adele Achem)
# Name: Name, dtype: object

# %%
sl
# Out:
# a                              Braund, Mr. Owen Harris
# b    Cumings, Mrs. John Bradley (Florence Briggs Th...
# c                               Heikkinen, Miss. Laina
# d         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# e                             Allen, Mr. William Henry
# f                                     Moran, Mr. James
# g                              McCarthy, Mr. Timothy J
# h                       Palsson, Master. Gosta Leonard
# i    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# j                  Nasser, Mrs. Nicholas (Adele Achem)
# dtype: object

# %%
s[0]
# Out:
# 'Braund, Mr. Owen Harris'

# %%
sl[0]
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_8608\1110252631.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sl[0]
# 'Braund, Mr. Owen Harris'

# %%
sl["b"]
# Out:
# 'Cumings, Mrs. John Bradley (Florence Briggs Thayer)'

# %%
s2 = sl. _append(s)

# %%
s2
# Out:
# a                              Braund, Mr. Owen Harris
# b    Cumings, Mrs. John Bradley (Florence Briggs Th...
# c                               Heikkinen, Miss. Laina
# d         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# e                             Allen, Mr. William Henry
# f                                     Moran, Mr. James
# g                              McCarthy, Mr. Timothy J
# h                       Palsson, Master. Gosta Leonard
# i    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# j                  Nasser, Mrs. Nicholas (Adele Achem)
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# ...

# %%
s2[0]
# Out:
# 'Braund, Mr. Owen Harris'

# %%
s2[4]
# Out:
# 'Allen, Mr. William Henry'

# %%
s3 = pd.Series([4,5,9,95,95,985], index=[2,4,46514,641651,8548135,1])

s4 = pd.Series([1,4,5,854,6549,1564,98],index=[15,548,4984,65655,5,4,1])

# %%
s3
# Out:
# 2            4
# 4            5
# 46514        9
# 641651      95
# 8548135     95
# 1          985
# dtype: int64

# %%
s6= s4. _append(s3)

# %%
s6
# Out:
# 15            1
# 548           4
# 4984          5
# 65655       854
# 5          6549
# 4          1564
# 1            98
# 2             4
# 4             5
# 46514         9
# 641651       95
# 8548135      95
# 1           985
# dtype: int64

# %%
s6[1]
# Out:
# 1     98
# 1    985
# dtype: int64

# %%
print(s3)
print(s4)
print(s3*s4)
# Out:
# 2            4
# 4            5
# 46514        9
# 641651      95
# 8548135     95
# 1          985
# dtype: int64
# 15          1
# 548         4
# 4984        5
# 65655     854
# 5        6549
# 4        1564
# 1          98
# dtype: int64
# 1          96530.0
# 2              NaN
# 4           7820.0
# 5              NaN
# 15             NaN
# 548            NaN
# 4984           NaN
# 46514          NaN
# 65655          NaN
# 641651         NaN
# 8548135        NaN
# dtype: float64

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'new_col'],
#       dtype='object')

# %%
# data.drop("PassengerId" , axis=1, inplace=True)

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.drop(3)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.drop(3,inplace=True)

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.set_index("Name",inplace=True)

# %%
data
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Allen, Mr. William Henry                                      5         0
# Moran, Mr. James                                              6         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
# ...

# %%
data.reset_index("Name", inplace=True)

# %%
data
# Out:
#                                                   Name  PassengerId  Survived  \
# 0                              Braund, Mr. Owen Harris            1         0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 2                               Heikkinen, Miss. Laina            3         1
# 3                             Allen, Mr. William Henry            5         0
# 4                                     Moran, Mr. James            6         0
# ..                                                 ...          ...       ...
# 885                              Montvila, Rev. Juozas          887         0
# 886                       Graham, Miss. Margaret Edith          888         1
# 887           Johnston, Miss. Catherine Helen "Carrie"          889         0
# 888                              Behr, Mr. Karl Howell          890         1
# 889                                Dooley, Mr. Patrick          891         0
#
# ...

# %%
d= {
    'Key1':[1,2,3,5,45],
    'Key2':[5,6,8,65,55],
    'Key3':[5,6,8,5,55]
}

# %%
pd.DataFrame(d)
# Out:
#    Key1  Key2  Key3
# 0     1     5     5
# 1     2     6     6
# 2     3     8     8
# 3     5    65     5
# 4    45    55    55

# %%
df1=pd.read_excel("extract-taxonomy.xlsx")

# %%
df1
# Out:
#                                     ConceptScheme URI  \
# 0   Prefixes for controlled vocabularies, schema a...
# 1                                              PREFIX
# 2                                              PREFIX
# 3                                              PREFIX
# 4                                              PREFIX
# 5                           Metadata about vocabulary
# 6                                           dct:title
# 7                                      skos:prefLabel
# 8                                     dct:description
# 9                                         dct:creator
# 10                                        dct:creator
# 11                                         dct:rights
# 12                                        pav:version
# 13                                      pav:createdOn
# 14                                  pav:lastUpdatedOn
# 15        Definition of terms (optionally properties)
# ...

# %%
df1.dropna(inplace=True)

# %%
df1
# Out:
#    ConceptScheme URI http://purl.org/extract/  \
# 16        Identifier        skos:prefLabel@en
#
#    Main GUPRI (i.e. PID) under which all terms are defined. Preference is to use PURLs or W3IDs as they provide permanent resolvable identifiers if they are properly configured and managed.  \
# 16                       skos:altLabel(separator=";")
#
#             Unnamed: 3                 Unnamed: 4  \
# 16  skos:definition@en  dct:source(separator=",")
#
#                      Unnamed: 5                      Unnamed: 6  \
# 16  skos:broader(separator=",")  skos:exactMatch(separator=",")
#
#                         Unnamed: 7             Unnamed: 8  \
# 16  skos:closeMatch(separator=",")  skos:editorialNote@en
#
#                     Unnamed: 9                     Unnamed: 10
# 16  dct:creator(separator=",")  dct:contributor(separator=",")

# %%
df2=pd.read_excel("extract-taxonomy.xlsx")

# %%
df2
# Out:
#                                     ConceptScheme URI  \
# 0   Prefixes for controlled vocabularies, schema a...
# 1                                              PREFIX
# 2                                              PREFIX
# 3                                              PREFIX
# 4                                              PREFIX
# 5                           Metadata about vocabulary
# 6                                           dct:title
# 7                                      skos:prefLabel
# 8                                     dct:description
# 9                                         dct:creator
# 10                                        dct:creator
# 11                                         dct:rights
# 12                                        pav:version
# 13                                      pav:createdOn
# 14                                  pav:lastUpdatedOn
# 15        Definition of terms (optionally properties)
# ...

# %%
df2.dropna(axis=1)
# Out:
#                                     ConceptScheme URI
# 0   Prefixes for controlled vocabularies, schema a...
# 1                                              PREFIX
# 2                                              PREFIX
# 3                                              PREFIX
# 4                                              PREFIX
# 5                           Metadata about vocabulary
# 6                                           dct:title
# 7                                      skos:prefLabel
# 8                                     dct:description
# 9                                         dct:creator
# 10                                        dct:creator
# 11                                         dct:rights
# 12                                        pav:version
# 13                                      pav:createdOn
# 14                                  pav:lastUpdatedOn
# 15        Definition of terms (optionally properties)
# ...

# %%
df2.fillna("abhishek")
# Out:
#                                     ConceptScheme URI  \
# 0   Prefixes for controlled vocabularies, schema a...
# 1                                              PREFIX
# 2                                              PREFIX
# 3                                              PREFIX
# 4                                              PREFIX
# 5                           Metadata about vocabulary
# 6                                           dct:title
# 7                                      skos:prefLabel
# 8                                     dct:description
# 9                                         dct:creator
# 10                                        dct:creator
# 11                                         dct:rights
# 12                                        pav:version
# 13                                      pav:createdOn
# 14                                  pav:lastUpdatedOn
# 15        Definition of terms (optionally properties)
# ...

# %%
data
# Out:
#                                                   Name  PassengerId  Survived  \
# 0                              Braund, Mr. Owen Harris            1         0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 2                               Heikkinen, Miss. Laina            3         1
# 3                             Allen, Mr. William Henry            5         0
# 4                                     Moran, Mr. James            6         0
# ..                                                 ...          ...       ...
# 885                              Montvila, Rev. Juozas          887         0
# 886                       Graham, Miss. Margaret Edith          888         1
# 887           Johnston, Miss. Catherine Helen "Carrie"          889         0
# 888                              Behr, Mr. Karl Howell          890         1
# 889                                Dooley, Mr. Patrick          891         0
#
# ...

# %%
g= data.groupby('Survived')

# %%
g

# %%
g.sum()
# Out:
#                                                        Name  PassengerId  \
# Survived
# 0         Braund, Mr. Owen HarrisAllen, Mr. William Henr...       245412
# 1         Cumings, Mrs. John Bradley (Florence Briggs Th...       151970
#
#           Pclass                                                Sex       Age  \
# Survived
# 0           1390  malemalemalemalemalemalemalefemalemalefemalema...  12985.50
# 1            666  femalefemalefemalefemalefemalefemalefemalemale...   8184.67
#
#           SibSp  Parch                                             Ticket  \
# Survived
# 0           304    181  A/5 2117137345033087717463349909A/5. 215134708...
# 1           161    159  PC 17599STON/O2. 3101282347742237736PP 9549113...
#
#                 Fare                                              Cabin  \
# Survived
# 0         12142.7199  E46C23 C25 C27B30C83F G73E31A5D26C110B58 B60D2...
# 1         16498.1294  C85G6C103D56A6B78D33C52B28F33C23 C25 C27D10 D1...
#
# ...

# %%
# g.mean()

# %%
# g.max()

# %%
p=data.groupby('Pclass')

# %%
p

# %%
p.sum()
# Out:
#                                                      Name  PassengerId  \
# Pclass
# 1       Cumings, Mrs. John Bradley (Florence Briggs Th...        99701
# 2       Nasser, Mrs. Nicholas (Adele Achem)Hewlett, Mr...        82056
# 3       Braund, Mr. Owen HarrisHeikkinen, Miss. LainaA...       215625
#
#         Survived                                                Sex      Age  \
# Pclass
# 1            135  femalemalefemalemalemalemalefemalemalemalefema...  7076.42
# 2             87  femalefemalemalemalemalemalefemalefemalefemale...  5168.83
# 3            119  malefemalemalemalemalefemalefemalemalemalefema...  8924.92
#
#         SibSp  Parch                                             Ticket  \
# Pclass
# 1          89     77  PC 175991746311378311378819950PC 17601PC 17569...
# 2          74     70  237736248706244373239865248698C.A. 2457911668S...
# 3         302    193  A/5 21171STON/O2. 3101282373450330877349909347...
#
# ...

# %%
# p.mean()

# %%
# p.median()

# %%
# p.max()['Fare']

# %%
data
# Out:
#                                                   Name  PassengerId  Survived  \
# 0                              Braund, Mr. Owen Harris            1         0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 2                               Heikkinen, Miss. Laina            3         1
# 3                             Allen, Mr. William Henry            5         0
# 4                                     Moran, Mr. James            6         0
# ..                                                 ...          ...       ...
# 885                              Montvila, Rev. Juozas          887         0
# 886                       Graham, Miss. Margaret Edith          888         1
# 887           Johnston, Miss. Catherine Helen "Carrie"          889         0
# 888                              Behr, Mr. Karl Howell          890         1
# 889                                Dooley, Mr. Patrick          891         0
#
# ...

# %%
data1 = data[['Survived' , 'Pclass' , 'Sex']][0:5]

# %%
data2 = data[['Survived' , 'Pclass' , 'Sex']][5:10]

# %%
data1
# Out:
#    Survived  Pclass     Sex
# 0         0       3    male
# 1         1       1  female
# 2         1       3  female
# 3         0       3    male
# 4         0       3    male

# %%
data2
# Out:
#    Survived  Pclass     Sex
# 5         0       1    male
# 6         0       3    male
# 7         1       3  female
# 8         1       2  female
# 9         1       3  female

# %%
pd.concat([data1,data2])
# Out:
#    Survived  Pclass     Sex
# 0         0       3    male
# 1         1       1  female
# 2         1       3  female
# 3         0       3    male
# 4         0       3    male
# 5         0       1    male
# 6         0       3    male
# 7         1       3  female
# 8         1       2  female
# 9         1       3  female

# %%
data3=pd.concat([data1,data2],axis=1)

# %%
data3.fillna("abhi")
# Out:
#   Survived Pclass     Sex Survived Pclass     Sex
# 0      0.0    3.0    male     abhi   abhi    abhi
# 1      1.0    1.0  female     abhi   abhi    abhi
# 2      1.0    3.0  female     abhi   abhi    abhi
# 3      0.0    3.0    male     abhi   abhi    abhi
# 4      0.0    3.0    male     abhi   abhi    abhi
# 5     abhi   abhi    abhi      0.0    1.0    male
# 6     abhi   abhi    abhi      0.0    3.0    male
# 7     abhi   abhi    abhi      1.0    3.0  female
# 8     abhi   abhi    abhi      1.0    2.0  female
# 9     abhi   abhi    abhi      1.0    3.0  female

# %%
data4 = pd.DataFrame({
    'Key1':[1,2,4,5,6],
    'Key2':[4,5,6,7,8],
    'Key3':[3,4,5,6,6],
})

# %%
data4
# Out:
#    Key1  Key2  Key3
# 0     1     4     3
# 1     2     5     4
# 2     4     6     5
# 3     5     7     6
# 4     6     8     6

# %%
data5 = pd.DataFrame({
    'Key1':[1,2,45,6,67],
    'Key4':[56,5,6,7,8],
    'Key5':[3,56,5,6,6],
})

# %%
data5
# Out:
#    Key1  Key4  Key5
# 0     1    56     3
# 1     2     5    56
# 2    45     6     5
# 3     6     7     6
# 4    67     8     6

# %%
pd.merge(data4,data5)
# Out:
#    Key1  Key2  Key3  Key4  Key5
# 0     1     4     3    56     3
# 1     2     5     4     5    56
# 2     6     8     6     7     6

# %%
pd.merge(data4,data5 , how='left')
# Out:
#    Key1  Key2  Key3  Key4  Key5
# 0     1     4     3  56.0   3.0
# 1     2     5     4   5.0  56.0
# 2     4     6     5   NaN   NaN
# 3     5     7     6   NaN   NaN
# 4     6     8     6   7.0   6.0

# %%
pd.merge(data4,data5 , how='right')
# Out:
#    Key1  Key2  Key3  Key4  Key5
# 0     1   4.0   3.0    56     3
# 1     2   5.0   4.0     5    56
# 2    45   NaN   NaN     6     5
# 3     6   8.0   6.0     7     6
# 4    67   NaN   NaN     8     6

# %%
pd.merge(data4,data5 , how='cross')
# Out:
#     Key1_x  Key2  Key3  Key1_y  Key4  Key5
# 0        1     4     3       1    56     3
# 1        1     4     3       2     5    56
# 2        1     4     3      45     6     5
# 3        1     4     3       6     7     6
# 4        1     4     3      67     8     6
# 5        2     5     4       1    56     3
# 6        2     5     4       2     5    56
# 7        2     5     4      45     6     5
# 8        2     5     4       6     7     6
# 9        2     5     4      67     8     6
# 10       4     6     5       1    56     3
# 11       4     6     5       2     5    56
# 12       4     6     5      45     6     5
# 13       4     6     5       6     7     6
# 14       4     6     5      67     8     6
# 15       5     7     6       1    56     3
# 16       5     7     6       2     5    56
# 17       5     7     6      45     6     5
# 18       5     7     6       6     7     6
# 19       5     7     6      67     8     6
# 20       6     8     6       1    56     3
# ...

# %%
pd.concat([data4,data5],axis=1)
# Out:
#    Key1  Key2  Key3  Key1  Key4  Key5
# 0     1     4     3     1    56     3
# 1     2     5     4     2     5    56
# 2     4     6     5    45     6     5
# 3     5     7     6     6     7     6
# 4     6     8     6    67     8     6

# %%
pd.merge(data4,data5, how='outer' , on='Key1')
# Out:
#    Key1  Key2  Key3  Key4  Key5
# 0     1   4.0   3.0  56.0   3.0
# 1     2   5.0   4.0   5.0  56.0
# 2     4   6.0   5.0   NaN   NaN
# 3     5   7.0   6.0   NaN   NaN
# 4     6   8.0   6.0   7.0   6.0
# 5    45   NaN   NaN   6.0   5.0
# 6    67   NaN   NaN   8.0   6.0

# %%
data4 = pd.DataFrame({
    'Key1':[1,2,4,5,6],
    'Key2':[4,5,6,7,8],
    'Key3':[3,4,5,6,6]},
    index = ['a','b','c','d','e']
)

# %%
data5 = pd.DataFrame({
    'Key11':[1,2,45,6,67],
    'Key22':[56,5,6,7,8],
    'Key33':[3,56,5,6,6]},
    index = ['a','b','h','j','k']
)

# %%
data4.join(data5).fillna('abhi')
# Out:
#    Key1  Key2  Key3 Key11 Key22 Key33
# a     1     4     3   1.0  56.0   3.0
# b     2     5     4   2.0   5.0  56.0
# c     4     6     5  abhi  abhi  abhi
# d     5     7     6  abhi  abhi  abhi
# e     6     8     6  abhi  abhi  abhi

# %%
data4.join(data5, how='right')
# Out:
#    Key1  Key2  Key3  Key11  Key22  Key33
# a   1.0   4.0   3.0      1     56      3
# b   2.0   5.0   4.0      2      5     56
# h   NaN   NaN   NaN     45      6      5
# j   NaN   NaN   NaN      6      7      6
# k   NaN   NaN   NaN     67      8      6

# %%
data4.join(data5, how='left')
# Out:
#    Key1  Key2  Key3  Key11  Key22  Key33
# a     1     4     3    1.0   56.0    3.0
# b     2     5     4    2.0    5.0   56.0
# c     4     6     5    NaN    NaN    NaN
# d     5     7     6    NaN    NaN    NaN
# e     6     8     6    NaN    NaN    NaN

# %%
data4.join(data5, how='inner')
# Out:
#    Key1  Key2  Key3  Key11  Key22  Key33
# a     1     4     3      1     56      3
# b     2     5     4      2      5     56

# %%
data4.join(data5, how='outer')
# Out:
#    Key1  Key2  Key3  Key11  Key22  Key33
# a   1.0   4.0   3.0    1.0   56.0    3.0
# b   2.0   5.0   4.0    2.0    5.0   56.0
# c   4.0   6.0   5.0    NaN    NaN    NaN
# d   5.0   7.0   6.0    NaN    NaN    NaN
# e   6.0   8.0   6.0    NaN    NaN    NaN
# h   NaN   NaN   NaN   45.0    6.0    5.0
# j   NaN   NaN   NaN    6.0    7.0    6.0
# k   NaN   NaN   NaN   67.0    8.0    6.0

# %%
data['Fare_INR'] = data['Fare'].apply(lambda x : x*80)

# %%
data.head()
# Out:
#                                                 Name  PassengerId  Survived  \
# 0                            Braund, Mr. Owen Harris            1         0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 2                             Heikkinen, Miss. Laina            3         1
# 3                           Allen, Mr. William Henry            5         0
# 4                                   Moran, Mr. James            6         0
#
#    Pclass     Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# 0       3    male  22.0      1      0         A/5 21171   7.2500   NaN
# 1       1  female  38.0      1      0          PC 17599  71.2833   C85
# 2       3  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN
# 3       3    male  35.0      0      0            373450   8.0500   NaN
# 4       3    male   NaN      0      0            330877   8.4583   NaN
#
#   Embarked  new_col  Fare_INR
# 0        S        4   580.000
# ...

# %%
def euro_inr(x):
    return x*80
data['Fare_INR'] = data['Fare'].apply(euro_inr)

# %%
data['Fare_INR']
# Out:
# 0       580.000
# 1      5702.664
# 2       634.000
# 3       644.000
# 4       676.664
#          ...
# 885    1040.000
# 886    2400.000
# 887    1876.000
# 888    2400.000
# 889     620.000
# Name: Fare_INR, Length: 890, dtype: float64

# %%
data['name_lenght'] = data['Name'].apply(len)

# %%
data.head()
# Out:
#                                                 Name  PassengerId  Survived  \
# 0                            Braund, Mr. Owen Harris            1         0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 2                             Heikkinen, Miss. Laina            3         1
# 3                           Allen, Mr. William Henry            5         0
# 4                                   Moran, Mr. James            6         0
#
#    Pclass     Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# 0       3    male  22.0      1      0         A/5 21171   7.2500   NaN
# 1       1  female  38.0      1      0          PC 17599  71.2833   C85
# 2       3  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN
# 3       3    male  35.0      0      0            373450   8.0500   NaN
# 4       3    male   NaN      0      0            330877   8.4583   NaN
#
#   Embarked  new_col  Fare_INR  name_lenght
# ...

# %%
def cat_fare(x):
    if x<10:
        return "cheap"
    elif x>=10 and x<20:
        return 'mid'
    else:
        return 'high'

# %%
data['cat_fare']=data['Fare'].apply(cat_fare)

# %%
data['cat_fare']
# Out:
# 0      cheap
# 1       high
# 2      cheap
# 3      cheap
# 4      cheap
#        ...
# 885      mid
# 886     high
# 887     high
# 888     high
# 889    cheap
# Name: cat_fare, Length: 890, dtype: object

# %%
data.head()
# Out:
#                                                 Name  PassengerId  Survived  \
# 0                            Braund, Mr. Owen Harris            1         0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 2                             Heikkinen, Miss. Laina            3         1
# 3                           Allen, Mr. William Henry            5         0
# 4                                   Moran, Mr. James            6         0
#
#    Pclass     Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# 0       3    male  22.0      1      0         A/5 21171   7.2500   NaN
# 1       1  female  38.0      1      0          PC 17599  71.2833   C85
# 2       3  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN
# 3       3    male  35.0      0      0            373450   8.0500   NaN
# 4       3    male   NaN      0      0            330877   8.4583   NaN
#
#   Embarked  new_col  Fare_INR  name_lenght cat_fare
# ...

# %%
data9 = {
    "a":[1,2,5,6,6],
    "b":[2,3,5,6,5],
    "c":["Abhi","Amit","Aniket","Mayank","Ravi"]
}

# %%
data9 = pd.DataFrame(data)

# %%
data9
# Out:
#                                                   Name  PassengerId  Survived  \
# 0                              Braund, Mr. Owen Harris            1         0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 2                               Heikkinen, Miss. Laina            3         1
# 3                             Allen, Mr. William Henry            5         0
# 4                                     Moran, Mr. James            6         0
# ..                                                 ...          ...       ...
# 885                              Montvila, Rev. Juozas          887         0
# 886                       Graham, Miss. Margaret Edith          888         1
# 887           Johnston, Miss. Catherine Helen "Carrie"          889         0
# 888                              Behr, Mr. Karl Howell          890         1
# 889                                Dooley, Mr. Patrick          891         0
#
# ...

# %%
# data=data.reset_index("a", inplace=True)
# data = data.reset_index()
# data = data.reset_index()

# %%
data1 = pd.DataFrame(data9, index=["a","b","c","d","e"])

# %%
data1
# Out:
#   Name  PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch Ticket  Fare  \
# a  NaN          NaN       NaN     NaN  NaN  NaN    NaN    NaN    NaN   NaN
# b  NaN          NaN       NaN     NaN  NaN  NaN    NaN    NaN    NaN   NaN
# c  NaN          NaN       NaN     NaN  NaN  NaN    NaN    NaN    NaN   NaN
# d  NaN          NaN       NaN     NaN  NaN  NaN    NaN    NaN    NaN   NaN
# e  NaN          NaN       NaN     NaN  NaN  NaN    NaN    NaN    NaN   NaN
#
#   Cabin Embarked  new_col  Fare_INR  name_lenght cat_fare
# a   NaN      NaN      NaN       NaN          NaN      NaN
# b   NaN      NaN      NaN       NaN          NaN      NaN
# c   NaN      NaN      NaN       NaN          NaN      NaN
# d   NaN      NaN      NaN       NaN          NaN      NaN
# e   NaN      NaN      NaN       NaN          NaN      NaN

# %%
data1.reindex(["b","d","a","c"])
# Out:
#   Name  PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch Ticket  Fare  \
# b  NaN          NaN       NaN     NaN  NaN  NaN    NaN    NaN    NaN   NaN
# d  NaN          NaN       NaN     NaN  NaN  NaN    NaN    NaN    NaN   NaN
# a  NaN          NaN       NaN     NaN  NaN  NaN    NaN    NaN    NaN   NaN
# c  NaN          NaN       NaN     NaN  NaN  NaN    NaN    NaN    NaN   NaN
#
#   Cabin Embarked  new_col  Fare_INR  name_lenght cat_fare
# b   NaN      NaN      NaN       NaN          NaN      NaN
# d   NaN      NaN      NaN       NaN          NaN      NaN
# a   NaN      NaN      NaN       NaN          NaN      NaN
# c   NaN      NaN      NaN       NaN          NaN      NaN

# %%
data1
# Out:
#   Name  PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch Ticket  Fare  \
# a  NaN          NaN       NaN     NaN  NaN  NaN    NaN    NaN    NaN   NaN
# b  NaN          NaN       NaN     NaN  NaN  NaN    NaN    NaN    NaN   NaN
# c  NaN          NaN       NaN     NaN  NaN  NaN    NaN    NaN    NaN   NaN
# d  NaN          NaN       NaN     NaN  NaN  NaN    NaN    NaN    NaN   NaN
# e  NaN          NaN       NaN     NaN  NaN  NaN    NaN    NaN    NaN   NaN
#
#   Cabin Embarked  new_col  Fare_INR  name_lenght cat_fare
# a   NaN      NaN      NaN       NaN          NaN      NaN
# b   NaN      NaN      NaN       NaN          NaN      NaN
# c   NaN      NaN      NaN       NaN          NaN      NaN
# d   NaN      NaN      NaN       NaN          NaN      NaN
# e   NaN      NaN      NaN       NaN          NaN      NaN

# %%
for i in data1.iterrows():
    print(i)
# Out:
# ('a', Name           NaN
# PassengerId    NaN
# Survived       NaN
# Pclass         NaN
# Sex            NaN
# Age            NaN
# SibSp          NaN
# Parch          NaN
# Ticket         NaN
# Fare           NaN
# Cabin          NaN
# Embarked       NaN
# new_col        NaN
# Fare_INR       NaN
# name_lenght    NaN
# cat_fare       NaN
# Name: a, dtype: object)
# ('b', Name           NaN
# PassengerId    NaN
# Survived       NaN
# Pclass         NaN
# Sex            NaN
# Age            NaN
# SibSp          NaN
# Parch          NaN
# Ticket         NaN
# Fare           NaN
# Cabin          NaN
# Embarked       NaN
# new_col        NaN
# Fare_INR       NaN
# name_lenght    NaN
# cat_fare       NaN
# Name: b, dtype: object)
# ('c', Name           NaN
# PassengerId    NaN
# Survived       NaN
# Pclass         NaN
# Sex            NaN
# Age            NaN
# SibSp          NaN
# Parch          NaN
# Ticket         NaN
# Fare           NaN
# Cabin          NaN
# Embarked       NaN
# ...

# %%
for i in data1.items():
    print(i)
    
    
#     print(i)
# Out:
# ('Name', a    NaN
# b    NaN
# c    NaN
# d    NaN
# e    NaN
# Name: Name, dtype: object)
# ('PassengerId', a   NaN
# b   NaN
# c   NaN
# d   NaN
# e   NaN
# Name: PassengerId, dtype: float64)
# ('Survived', a   NaN
# b   NaN
# c   NaN
# d   NaN
# e   NaN
# Name: Survived, dtype: float64)
# ('Pclass', a   NaN
# b   NaN
# c   NaN
# d   NaN
# e   NaN
# Name: Pclass, dtype: float64)
# ('Sex', a    NaN
# b    NaN
# c    NaN
# d    NaN
# e    NaN
# Name: Sex, dtype: object)
# ('Age', a   NaN
# b   NaN
# c   NaN
# d   NaN
# e   NaN
# Name: Age, dtype: float64)
# ('SibSp', a   NaN
# b   NaN
# c   NaN
# d   NaN
# e   NaN
# Name: SibSp, dtype: float64)
# ('Parch', a   NaN
# b   NaN
# c   NaN
# d   NaN
# e   NaN
# Name: Parch, dtype: float64)
# ('Ticket', a    NaN
# b    NaN
# c    NaN
# d    NaN
# e    NaN
# Name: Ticket, dtype: object)
# ('Fare', a   NaN
# b   NaN
# c   NaN
# d   NaN
# e   NaN
# Name: Fare, dtype: float64)
# ('Cabin', a    NaN
# b    NaN
# c    NaN
# d    NaN
# e    NaN
# ...

# %%
# !pip install --upgrade pandas

# %%
# ! pip install --upgrade pip

# %%
#  !pip install --upgrade pip

# %%
# import pandas as pd

# %%
# !pip install pandas==specific-higher-version

# %%
# df3 = pd.data_range(start="2023-03-23" ,end="2023-05-23")

# %%
# !python.exe -m pip install --upgrade pip

# %%
# !pip install --upgrade pandas

# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# date = pd.data_range(start="2023-03-23" ,end="2023-05-23")

# %%
# df_data=pd.DataFrame({'date':date})

# %%
data = ["Abhi" ,"Mayank", "Amit" , "Aniket" ,"Abhi" , "Abhi"]

# %%
cat = pd.Categorical(data)

# %%
cat
# Out:
# ['Abhi', 'Mayank', 'Amit', 'Aniket', 'Abhi', 'Abhi']
# Categories (4, object): ['Abhi', 'Amit', 'Aniket', 'Mayank']

# %%
cat.value_counts()
# Out:
# Abhi      3
# Amit      1
# Aniket    1
# Mayank    1
# Name: count, dtype: int64

# %%
d = pd.Series([1,5,6,9,5,2])

# %%
d
# Out:
# 0    1
# 1    5
# 2    6
# 3    9
# 4    5
# 5    2
# dtype: int64

# %%
d.plot()
# Out:
# <Axes: >

# %%
df = pd.DataFrame({
    "a":[1,2,3,6,5,65],
    "b":[2,6,5,9,6,36]
})

# %%
df
# Out:
#     a   b
# 0   1   2
# 1   2   6
# 2   3   5
# 3   6   9
# 4   5   6
# 5  65  36

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.plot(x="a", y="b")
# Out:
# <Axes: >

# %%
df.plot.scatter(x="a", y="b")
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %%
df.plot.density(x="a" , y="b")
# Out:
# <Axes: ylabel='Density'>

# %%
df.plot.area(x="a" , y="b")
# Out:
# <Axes: xlabel='a'>

# %%
d = pd.Series([1,5,6,9,5,2])

# %%
d
# Out:
# 0    1
# 1    5
# 2    6
# 3    9
# 4    5
# 5    2
# dtype: int64

# %%
d.plot.pie()
# Out:
# <Axes: >
